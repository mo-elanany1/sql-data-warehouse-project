# %%
a = 10
b = 5

print(a + b)
print(a ** b)
print(a // b)

print(20 % 3)
# Out:
# 15
# 100000
# 2
# 2

# %% [markdown]
# ## Logical Operators

# %%
age = 28 
country = "Egypt"

print(age > 18)
print(country == "Egypt")
print(age > 18 and country == "USA")
print(age > 18 or country == "Egypt")
print(not(age > 18))
# Out:
# True
# True
# False
# True
# False

# %% [markdown]
# ## Input

# %%
frist_name = input("Enter your first name: ")

print("Hello, " + frist_name + "! Welcome to Python programming.")
# Out:
# Hello, Mohamed! Welcome to Python programming.

# %%
full_name = input("Enter your first name: ")
age = input("Enter your age: ")

print("Hello, " + full_name + "! Welcome to Python programming."+ "Your age is " + age + ".")

print(type(age))
# Out:
# Hello, 0000000! Welcome to Python programming.Your age is 20.
# <class 'str'>

# %%
text = '100'
print(int(text))
# Out:
# 100

# %%
user_name = input("Enter your name: ")
password = input("Enter your password: ")

print(user_name == 'M@M' and password ==   '1234')
# Out:
# False

# %%
full_name = input("Enter your first name: ")
user_name = input("Enter your name: ")
password = input("Enter your password: ")

print(full_name == 'Mohamed Esam' or (user_name == 'M@M' and password ==   '1234'))
# Out:
# True

# %%
customer_name = input("Enter your name: ")

# lower 
print(customer_name.lower())   

# upper
print(customer_name.upper())

# capitalize
print(customer_name.capitalize())

# strip
print(customer_name.strip())
# Out:
# mohamed mostafs elenany
# MOHAMED MOSTAFS ELENANY
# Mohamed mostafs elenany
# mohamed mostafs elenany

# %%
text = "Hello, World!"

print(text.replace("World", "Python"))
# Out:
# Hello, Python!

# %%
name = input("Enter your name: ").capitalize()

if name == "Esam":
    print("Good")
elif name == "Mohamed":
    print("Very Good")
else:
    print("Name not recognized")
# Out:
# Name not recognized

# %% [markdown]
# ## Task

# %%
name = input("Enter your name: ").capitalize()
age = int(input("Enter your age: "))
job = input("Enter your job: ").lower()


if  age > 18:
    print('10$')
elif job == "student" and age > 18:
    print('Free$')
elif age < 18:
    print('50% off')
else:
    print('25$')
# Out:
# 25$

# %%
try:
    name = input("Enter your name: ").capitalize()
    age = int(input("Enter your age: "))
    job = input("Enter your job: ").lower()


    if  age > 18:
        print('10$')
    elif job == "student" and age > 18:
        print('Free$')
    elif age < 18:
        print('50% off')
    else:
        print('25$')
except ValueError:
    print("an error occurred.")
# Out:
# 10$
